# %% [markdown]
# # Simulación de Procesos Financieros

# %% [markdown]
# Con esta herramienta podre hacer ecuaciones de la siguiente forma:

# %% [markdown]
# >$$\nabla\cdot \mathbf{D}=\rho\quad    x(t) = \frac{1}{1+ (\frac{1}{x_{0}}- 1) e^{-rt}}$$
# ___

# %% [markdown]
# Ademas de representarlas, usando librerias como estas:

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def logisol(t, x0, r):
    return 1/(1 + (1/x0 - 1) * np.exp(-r * t))

# %%
x = np.linspace(0,10)
for r in np.arange(-1, 1,.1):
    plt.plot(x, logisol(x, 0.05, r))
plt.show()

# %% [markdown]
# Puedes usar encabezados para diversas cosas

# %% [markdown]
# - **1** Frutas
#     - *1.1* Sandia
#     - *1.2* Limon
#     - *1.3* Papaya

# %% [markdown]
# ## Tambien puedes poner fotografias

# %% [markdown]
# <img https://www.google.com.mx/url?sa=i&rct=j&q=&esrc=s&source=images&cd=&cad=rja&uact=8&ved=0ahUKEwjqisquz-_YAhUFbK0KHYc4Cm0QjRwIBw&url=http%3A%2F%2Fwww.travelzoo.com%2Fblog%2F7-ways-to-feel-the-love-in-cartagena-colombia%2F&psig=AOvVaw2vA8MD_eMhVTU9p5ofIb8g&ust=1516849579616696 />

# %% [markdown]
# <img style="center" src="http://www.travelzoo.com/blog/wp-content/uploads/2017/10/BANNERHEAD-960x477.jpg" width="250px" height="200px" alt="atom" />

# %%
hbudbawIYIDBIASBD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b26cbfeb377b> in <module>()
# ----> 1 hbudbawIYIDBIASBD
#
# NameError: name 'hbudbawIYIDBIASBD' is not defined
