# %%
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n = 0
z = 0
k = 0
dinero = 0
mon = 0
t = 0
tir = 0
tirtot = []
tiradas = []
gan = []
efe = 0
cash = []
dsim = []
gand = []
dtotal = []
d = []
di = []
din = []
juegos = []
probmas150 = []

# %%
while t < 100 :
    num = np.random.randint(0,2)
    if num == 0:
        n += 1
        z = 0
        if n == 3:
            n = 0
            tiradas.append(k)
            k = 0
            dinero += 8
            
    elif num == 1:
        z += 1
        n = 0
        if z == 3:
            z = 0
            tiradas.append(k)
            k = 0
            dinero += 8
    dinero -= 1
    t += 1
    k += 1

# %%
promtir = np.mean(tiradas)
desvesttir = np.std(tiradas)
print("Promedio:",promtir,"Desv. est.:",desvesttir)
plt.hist(tiradas)
# Out:
# Promedio: 6.88275862069 Desv. est.: 5.25029187796
# 145

# %%
mayores = [i for i in tiradas if i > 9]
probmayor = len(mayores)/len(tiradas)
probmayor *= 100
menores = [i for i in tiradas if i < 4]
probmenor = len(menores)/len(tiradas)
probmenor *=100

# %%
for i in range(10):
    for j in range(100):
        num = np.random.randint(0,2)
        if num == 0:
            n += 1
            z = 0
            if n == 3:
                n = 0
                tiradas.append(k)
                k = 0
                dinero += 8

        elif num == 1:
            z += 1
            n = 0
            if z == 3:
                z = 0
                tiradas.append(k)
                k = 0
                dinero += 8
        dinero -= 1
        k += 1
        
    din.append(dinero)
    juegos.append(tiradas)
    dinero = 0

# %%
promdin = np.mean(din)
masprob = st.mode(din)
gandin = [i for i in din if i > 0]
probgandin = len(gandin)/len(din) * 100
fig, ax = plt.subplots(1,2)
ax[0].hist(juegos)
ax[1].hist(din)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-15-c20c0ce39cc9> in <module>()
#       1 promdin = np.mean(din)
# ----> 2 masprob = st.mode(din)
#       3 gandin = [i for i in din if i > 0]
#       4 probgandin = len(gandin)/len(din) * 100
#       5 fig, ax = plt.subplots(1,2)
#
# ~/anaconda3/lib/python3.6/statistics.py in mode(data)
#     505     elif table:
#     506         raise StatisticsError(
# --> 507                 'no unique mode; found %d equally common values' % len(table)
#     508                 )
#     509     else:
#
# StatisticsError: no unique mode; found 10 equally common values

# %%
dinero = 30
for i in range(10):   
    for j in range(1000):
        num = np.random.randint(0,2)
        if num == 0:
            n += 1
            z = 0
            if n == 3:
                n = 0
                tiradas.append(k)
                k = 0
                dinero += 8

        elif num == 1:
            z += 1
            n = 0
            if z == 3:
                z = 0
                tiradas.append(k)
                k = 0
                dinero += 8
        dinero -= 1
        k += 1
        tir += 1 

        if dinero < 1:
            break
            tir = 0

    tirtot.append(tir)
    din.append(dinero)
    juegos.append(tiradas)
    dinero = 30
    tir = 0

# %%
promtiros = np.mean(tirtot)
mas150 = [i for i in tirtot if i > 150]
probmas150 = len(mas150)/len(tirtot) * 100
plt.hist(tirtot)
# Out:
# (array([  0.,   0.,   0.,   0.,   0.,  10.,   0.,   0.,   0.,   0.]),
#  array([  999.5,   999.6,   999.7,   999.8,   999.9,  1000. ,  1000.1,
#          1000.2,  1000.3,  1000.4,  1000.5]),
#  <a list of 10 Patch objects>)

# %%
promtiros
# Out:
# 1000.0

# %%
for i in range(len(tirtot)):
    for j in range(len(tirtot[i])):
        if tirtot[i][j] > 150:
            probmas150.append(tirtot[i][j])

# %%
dias = [4,4,7,7,7,8,8,8,8,5,5,5,5,5,1,1,1,1,1,1]
plt.hist(dias)
# Out:
# (array([ 6.,  0.,  0.,  0.,  2.,  5.,  0.,  0.,  3.,  4.]),
#  array([ 1. ,  1.7,  2.4,  3.1,  3.8,  4.5,  5.2,  5.9,  6.6,  7.3,  8. ]),
#  <a list of 10 Patch objects>)

# %%
promdias = np.mean(dias)
promdias
# Out:
# 4.5999999999999996

# %%
def mant(x):
    
    np.random.uniform(0.1,2)
    np.random.uniform(3.5,9)
    if x == 2:
        mean = 4
    elif x == 3:
        mean = 3
    elif x == 4:
        mean = 2
        
    return sal

# %%
for i in range(10000):    
    while True:
        dado = np.random.randint(1,7)
        dado1 = np.random.randint(1,7)
        if dado + dado1 == 7 or dado + dado1 == 11:
            
            gan.append(1)
            break

        elif dado + dado1 == 2 or dado + dado1 ==3 or dado + dado1 == 12:
            
            gan.append(0)
            break

        elif 3 < dado + dado1 < 7 or 7 < dado + dado1 < 11:
            while True:
                dado = np.random.randint(1,7)
                dado1 = np.random.randint(1,7)
                if 3 < dado + dado1 < 7 or 7 < dado + dado1 < 11:
                    gan.append(1)
                    break

                elif dado + dado1 == 7:
                    gan.append(0)
                    break

# %%
ganar = [i for i in gan if i == 1]
probganar = len(ganar)/len(gan)*100
probganar
# Out:
# 75.72741448525264

# %%
for i in range(10):    
    while True:
        dado = np.random.randint(1,7)
        dado1 = np.random.randint(1,7)
        if dado + dado1 == 7 or dado + dado1 == 11:
            gan.append(1)
            efe += 50
            break

        elif dado + dado1 == 2 or dado + dado1 ==3 or dado + dado1 == 12:
            
            gan.append(0)
            efe -= 50
            break

        elif 3 < dado + dado1 < 7 or 7 < dado + dado1 < 11:
            while True:
                dado = np.random.randint(1,7)
                dado1 = np.random.randint(1,7)
                if 3 < dado + dado1 < 7 or 7 < dado + dado1 < 11:
                    gan.append(1)
                    efe += 50
                    break

                elif dado + dado1 == 7:
                    gan.append(0)
                    efe -= 50
                    break
                    
    cash.append(efe)
    efe = 0

# %%
promcash = np.mean(cash)
masprobcash = st.mode(cash)
gancash = [i for i in cash if i > 0]
probgan = len(gancash)/len(cash)*100
probgan
# Out:
# 90.0

# %%
for i in range(10000):
    num = np.random.uniform(.08,.121)
    
    di = 300000 * num
    
    d.append(di)
# Out:
# [31802.958391001433,
#  29358.122610199294,
#  27785.163064083827,
#  33031.87506553158,
#  32517.3753522274,
#  26207.766415350037,
#  26651.16930696291,
#  25669.59334743292,
#  26142.02782801203,
#  28715.117269151528,
#  30404.811109910544,
#  34694.481924611784,
#  31299.759853877276,
#  31260.10282062863,
#  36262.41578507001,
#  27560.304394539155,
#  31956.936623335718,
#  33185.571682544614,
#  31028.708206155545,
#  30909.305843870574,
#  28281.670385177833,
#  30326.805638993585,
#  32144.242282044746,
#  30696.721364828012,
#  35911.59207034107,
#  24356.20354088781,
#  27997.10298916249,
#  28331.514090016808,
#  27791.63001892149,
#  28632.43749214728,
#  27107.311053856218,
#  28058.06188079028,
#  36091.35585830874,
#  26283.003080984534,
#  31839.919266124776,
#  25871.85147076828,
#  32119.306370610935,
#  35661.96823124208,
#  33205.082304071184,
#  28528.837054171872,
#  25849.096713205465,
#  32094.92226813536,
#  28932.96045084518,
#  28883.21091967721,
#  35621.0112956148,
#  30097.740269260055,
#  31830.025446161664,
#  26761.672381391574,
#  25873.03559678512,
#  34966.11995586475,
#  31616.068848880164,
#  33176.602051177986,
#  32523.66093273263,
#  33880.514129838375,
#  26087.960951744524,
#  35662.74634917202,
#  35513.78459511399,
#  24640.505291991736,
#  ...]

# %%
promren = np.mean(d)
desvestren = np.std(d)
plt.hist(d)
# Out:
# (array([ 1967.,  2019.,  1994.,  1941.,  2021.,  2007.,  1970.,  2012.,
#          2032.,  2037.]),
#  array([ 24000.24221413,  25230.19232769,  26460.14244125,  27690.09255481,
#          28920.04266836,  30149.99278192,  31379.94289548,  32609.89300904,
#          33839.8431226 ,  35069.79323616,  36299.74334972]),
#  <a list of 10 Patch objects>)

# %%
for i in range(100):
    for j in range(6):
        num = np.random.uniform(.08,.121)
    
        di = 300000 * num

        d.append(di)
    mon = sum(d)
    dtotal.append(mon)

# %%
promdsim = np.mean(dtotal)
desvestdsim = np.std(dtotal)
plt.hist(dtotal)
# Out:
# (array([ 11.,  10.,   9.,  10.,  10.,  10.,  10.,  10.,  10.,  10.]),
#  array([   171456.48517449,   1956330.47538309,   3741204.46559169,
#           5526078.45580029,   7310952.44600889,   9095826.4362175 ,
#          10880700.4264261 ,  12665574.4166347 ,  14450448.4068433 ,
#          16235322.3970519 ,  18020196.3872605 ]),
#  <a list of 10 Patch objects>)

# %%
gand = [i for i in dtotal if i > 58000]
probgand = len(gand)/len(dtotal)* 100

gmin = [i for i in dtotal if i < 55000]
probmin = len(gmin)/len(dtotal) * 100
# Out:
# 0.0

# %%
for i in range(100):
    for j in range(6):
        num = np.random.randint(8,13)
        ran = np.random.randint(0,2)
        

        di = 300000 * num /100


        d.append(di)
    mon = sum(d)
    dtotal.append(mon)

# %%
entrenum = [i for i in dtotal if 53000 < i < 56000]
probentrenum = len(entrenum)/len(dtotal)
promd = np.mean(dtotal)
estdev = np.std(dtotal)
plt.hist(dtotal)
# Out:
# (array([ 10.,  10.,  10.,  10.,  10.,  10.,  10.,  10.,   9.,  11.]),
#  array([   177000.,   1948200.,   3719400.,   5490600.,   7261800.,
#           9033000.,  10804200.,  12575400.,  14346600.,  16117800.,
#          17889000.]),
#  <a list of 10 Patch objects>)
